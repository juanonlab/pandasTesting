# %%
# Biblio
# https://www.geeksforgeeks.org/python-pandas-dataframe-resample/
# https://stackabuse.com/pandas-library-for-data-visualization-in-python/

# import the necessary libraries
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot

# %%
# Show current path directory
os.getcwd()
# Out:
# 'C:\\Users\\juanp\\pandasTesting'

# %%
# Read house1_frag.csv data
house1_data = pd.read_csv('data\House_1.csv', delimiter = ',', parse_dates=[0], index_col=0)
house1_data = house1_data.dropna()
house1_data_filtered = house1_data[['Appliance8']]
monthly_resampled_Appliance_ALL = house1_data_filtered.resample('6H').mean()
monthly_resampled_Appliance8 = house1_data_filtered.Appliance8.resample('6H').mean() # 1H Hour, 1D Day, 6H Hour

# %%
# Show Appliance1 by Hour
monthly_resampled_Appliance8 = monthly_resampled_Appliance8[(monthly_resampled_Appliance8.index < '2015-06-10') | (monthly_resampled_Appliance8.index > '2015-06-17')]
monthly_resampled_Appliance8[(monthly_resampled_Appliance8.index < '2014-01-24') | (monthly_resampled_Appliance8.index > '2014-03-06')]
# Out:
# Time
# 2013-10-09 12:00:00     5.067997
# 2013-10-09 18:00:00    10.301058
# 2013-10-10 00:00:00     2.059725
# 2013-10-10 06:00:00     0.000000
# 2013-10-10 12:00:00    10.787332
# 2013-10-10 18:00:00    14.748785
# 2013-10-11 00:00:00     0.239695
# 2013-10-11 06:00:00     0.000000
# 2013-10-11 12:00:00     0.000000
# 2013-10-11 18:00:00     0.000000
# 2013-10-12 00:00:00     0.245560
# 2013-10-12 06:00:00     0.000000
# 2013-10-12 12:00:00     0.000000
# 2013-10-12 18:00:00     0.000000
# 2013-10-13 00:00:00     0.251045
# 2013-10-13 06:00:00     0.000000
# 2013-10-13 12:00:00     0.000000
# 2013-10-13 18:00:00     0.000000
# 2013-10-14 00:00:00     0.249861
# 2013-10-14 06:00:00     0.000000
# 2013-10-14 12:00:00     0.000000
# 2013-10-14 18:00:00     0.000000
# 2013-10-15 00:00:00     0.261891
# 2013-10-15 06:00:00     0.000000
# 2013-10-15 12:00:00     0.000000
# 2013-10-15 18:00:00     0.000000
# 2013-10-16 00:00:00     0.255886
# 2013-10-16 06:00:00     0.000000
# 2013-10-16 12:00:00     0.000000
# 2013-10-16 18:00:00     0.000000
#                          ...
# 2015-07-03 00:00:00     0.249144
# 2015-07-03 06:00:00     0.000000
# 2015-07-03 12:00:00    13.437403
# 2015-07-03 18:00:00    17.384375
# 2015-07-04 00:00:00     3.910836
# 2015-07-04 06:00:00    10.031618
# 2015-07-04 12:00:00    21.467492
# 2015-07-04 18:00:00    32.125580
# 2015-07-05 00:00:00     1.957427
# 2015-07-05 06:00:00     0.000000
# 2015-07-05 12:00:00     0.000000
# 2015-07-05 18:00:00    20.698762
# 2015-07-06 00:00:00     0.244955
# 2015-07-06 06:00:00     0.000000
# 2015-07-06 12:00:00    27.200745
# 2015-07-06 18:00:00    31.267247
# 2015-07-07 00:00:00     0.237799
# 2015-07-07 06:00:00     3.583675
# 2015-07-07 12:00:00     9.873838
# 2015-07-07 18:00:00    21.628607
# 2015-07-08 00:00:00     1.772759
# 2015-07-08 06:00:00     0.000000
# 2015-07-08 12:00:00     0.079676
# 2015-07-08 18:00:00     3.814214
# 2015-07-09 00:00:00     0.700404
# 2015-07-09 06:00:00     0.000000
# 2015-07-09 12:00:00     0.000000
# 2015-07-09 18:00:00     2.960833
# 2015-07-10 00:00:00     2.149392
# 2015-07-10 06:00:00     0.000000
# Name: Appliance8, Length: 2362, dtype: float64

# %%
# House_1_16.csv ( NO DATA Line 273100) 
monthly_resampled_Appliance_graph = monthly_resampled_Appliance_ALL[(monthly_resampled_Appliance_ALL.index < '2015-06-10') | (monthly_resampled_Appliance_ALL.index > '2015-06-17')]

# House_1_3.csv ( NO DATA Line 134624) 
monthly_resampled_Appliance_graph = monthly_resampled_Appliance_graph[(monthly_resampled_Appliance_graph.index < '2014-01-24') | (monthly_resampled_Appliance_graph.index > '2014-03-06')]

# Show Filtered data
monthly_resampled_Appliance_graph
# Out:
#                      Appliance8
# Time
# 2013-10-09 12:00:00    5.067997
# 2013-10-09 18:00:00   10.301058
# 2013-10-10 00:00:00    2.059725
# 2013-10-10 06:00:00    0.000000
# 2013-10-10 12:00:00   10.787332
# 2013-10-10 18:00:00   14.748785
# 2013-10-11 00:00:00    0.239695
# 2013-10-11 06:00:00    0.000000
# 2013-10-11 12:00:00    0.000000
# 2013-10-11 18:00:00    0.000000
# 2013-10-12 00:00:00    0.245560
# 2013-10-12 06:00:00    0.000000
# 2013-10-12 12:00:00    0.000000
# 2013-10-12 18:00:00    0.000000
# 2013-10-13 00:00:00    0.251045
# 2013-10-13 06:00:00    0.000000
# 2013-10-13 12:00:00    0.000000
# 2013-10-13 18:00:00    0.000000
# 2013-10-14 00:00:00    0.249861
# 2013-10-14 06:00:00    0.000000
# 2013-10-14 12:00:00    0.000000
# 2013-10-14 18:00:00    0.000000
# 2013-10-15 00:00:00    0.261891
# 2013-10-15 06:00:00    0.000000
# 2013-10-15 12:00:00    0.000000
# 2013-10-15 18:00:00    0.000000
# 2013-10-16 00:00:00    0.255886
# 2013-10-16 06:00:00    0.000000
# 2013-10-16 12:00:00    0.000000
# 2013-10-16 18:00:00    0.000000
# ...                         ...
# 2015-07-03 00:00:00    0.249144
# 2015-07-03 06:00:00    0.000000
# 2015-07-03 12:00:00   13.437403
# 2015-07-03 18:00:00   17.384375
# 2015-07-04 00:00:00    3.910836
# 2015-07-04 06:00:00   10.031618
# 2015-07-04 12:00:00   21.467492
# 2015-07-04 18:00:00   32.125580
# 2015-07-05 00:00:00    1.957427
# 2015-07-05 06:00:00    0.000000
# 2015-07-05 12:00:00    0.000000
# 2015-07-05 18:00:00   20.698762
# 2015-07-06 00:00:00    0.244955
# 2015-07-06 06:00:00    0.000000
# 2015-07-06 12:00:00   27.200745
# 2015-07-06 18:00:00   31.267247
# 2015-07-07 00:00:00    0.237799
# 2015-07-07 06:00:00    3.583675
# 2015-07-07 12:00:00    9.873838
# 2015-07-07 18:00:00   21.628607
# 2015-07-08 00:00:00    1.772759
# 2015-07-08 06:00:00    0.000000
# 2015-07-08 12:00:00    0.079676
# 2015-07-08 18:00:00    3.814214
# 2015-07-09 00:00:00    0.700404
# 2015-07-09 06:00:00    0.000000
# 2015-07-09 12:00:00    0.000000
# 2015-07-09 18:00:00    2.960833
# 2015-07-10 00:00:00    2.149392
# 2015-07-10 06:00:00    0.000000
#
# [2362 rows x 1 columns]

# %%
# Show Graph
# Quit Time
interpolated = monthly_resampled_Appliance_graph.interpolate(method='spline', order=2)
print(interpolated.head(10))
interpolated.plot()
pyplot.show()
# Out:
#                      Appliance8
# Time
# 2013-10-09 12:00:00    5.067997
# 2013-10-09 18:00:00   10.301058
# 2013-10-10 00:00:00    2.059725
# 2013-10-10 06:00:00    0.000000
# 2013-10-10 12:00:00   10.787332
# 2013-10-10 18:00:00   14.748785
# 2013-10-11 00:00:00    0.239695
# 2013-10-11 06:00:00    0.000000
# 2013-10-11 12:00:00    0.000000
# 2013-10-11 18:00:00    0.000000
